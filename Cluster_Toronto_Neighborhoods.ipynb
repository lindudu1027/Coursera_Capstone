# %% [markdown]
# # Transform the table

# %% [markdown]
# #### Import library and read the wiki page table

# %%
import numpy as np

# %%
import pandas as pd
data=pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')

# %%
data=data[0]
data
# Out:
#     Postal Code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                           Neighborhood
# 0                                                  NaN
# 1                                                  NaN
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# ..                                                 ...
# 175                                                NaN
# 176                                                NaN
# ...

# %% [markdown]
# #### Delete the "Not assigned" rows

# %%
df=data[data.Borough != "Not assigned"].reset_index(drop=True)

# %%
df
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Regent Park, Harbourfront
# 3                     Lawrence Manor, Lawrence Heights
# 4          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# ...

# %% [markdown]
# #### Check the NaN value in Neighborhood column

# %%
df.Neighborhood.isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Find the shape of the table

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# # Find the geo location of each postal code

# %%
import geocoder # import geocoder

i=0
for item in df['Postal Code']:
    lat_lng_coords = None
    while(lat_lng_coords is None):
        g = geocoder.google('{}, Toronto, Ontario'.format(item))
        lat_lng_coords = g.latlng
        latitude = lat_lng_coords[0]
        longitude = lat_lng_coords[1]
        df['latitude'][i]=latitude
        df['longitude'][i]=longitude
    i=i+1
    
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-2e59f0b7f5f9> in <module>
#       7         g = geocoder.google('{}, Toronto, Ontario'.format(item))
#       8         lat_lng_coords = g.latlng
# ----> 9         latitude = lat_lng_coords[0]
#      10         longitude = lat_lng_coords[1]
#      11         df['latitude'][i]=latitude
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# #### geocoder doesn't work, so import the csv

# %%
geo=pd.read_csv("/Users/linzhixin/Downloads/Geospatial_Coordinates.csv")
geo
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# ..          ...        ...        ...
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %% [markdown]
# #### merge two table

# %%
geolocation=pd.merge(df, geo, on='Postal Code')
geolocation
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Regent Park, Harbourfront  43.654260 -79.360636
# 3                     Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4          Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# ..                                                 ...        ...        ...
# ...

# %% [markdown]
# # Cluster

# %%
import folium
import json
from pandas.io.json import json_normalize
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
latitude=43.651070
longitude= -79.347015

# %%
geolocation.groupby('Borough').mean()
# Out:
#                    Latitude  Longitude
# Borough
# Central Toronto   43.701980 -79.398954
# Downtown Toronto  43.654597 -79.383972
# East Toronto      43.669436 -79.324654
# East York         43.700303 -79.335851
# Etobicoke         43.660043 -79.542074
# Mississauga       43.636966 -79.615819
# North York        43.750727 -79.429338
# Scarborough       43.766229 -79.249085
# West Toronto      43.652653 -79.449290
# York              43.690797 -79.472633

# %% [markdown]
# #### Analyzing those borough name contains Toronto

# %%
toronto=geolocation[geolocation.Borough.str.contains("Toronto")].reset_index(drop=True)
toronto
# Out:
#    Postal Code           Borough  \
# 0          M5A  Downtown Toronto
# 1          M7A  Downtown Toronto
# 2          M5B  Downtown Toronto
# 3          M5C  Downtown Toronto
# 4          M4E      East Toronto
# 5          M5E  Downtown Toronto
# 6          M5G  Downtown Toronto
# 7          M6G  Downtown Toronto
# 8          M5H  Downtown Toronto
# 9          M6H      West Toronto
# 10         M5J  Downtown Toronto
# 11         M6J      West Toronto
# 12         M4K      East Toronto
# 13         M5K  Downtown Toronto
# 14         M6K      West Toronto
# 15         M4L      East Toronto
# 16         M5L  Downtown Toronto
# 17         M4M      East Toronto
# 18         M4N   Central Toronto
# 19         M5N   Central Toronto
# 20         M4P   Central Toronto
# 21         M5P   Central Toronto
# 22         M6P      West Toronto
# 23         M4R   Central Toronto
# 24         M5R   Central Toronto
# 25         M6R      West Toronto
# 26         M4S   Central Toronto
# ...

# %% [markdown]
# #### Map of Toronto

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=12)

# add markers to map
for lat, lng, borough, neighborhood in zip(toronto['Latitude'], toronto['Longitude'], toronto['Borough'], toronto['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Foursquare API, I deleted

# %%
CLIENT_ID =  # your Foursquare ID
CLIENT_SECRET =  # your Foursquare Secret
VERSION =  # Foursquare API version

# %%
import requests
LIMIT=100
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        #print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# #### Retrive venues information

# %%
toronto_venues = getNearbyVenues(names=toronto['Postal Code'],
                                   latitudes=toronto['Latitude'],
                                   longitudes=toronto['Longitude']
                                  )

toronto_venues
# Out:
#      Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0             M5A              43.654260              -79.360636
# 1             M5A              43.654260              -79.360636
# 2             M5A              43.654260              -79.360636
# 3             M5A              43.654260              -79.360636
# 4             M5A              43.654260              -79.360636
# ...           ...                    ...                     ...
# 1599          M7Y              43.662744              -79.321558
# 1600          M7Y              43.662744              -79.321558
# 1601          M7Y              43.662744              -79.321558
# 1602          M7Y              43.662744              -79.321558
# 1603          M7Y              43.662744              -79.321558
#
#                           Venue  Venue Latitude  Venue Longitude  \
# 0              Roselle Desserts       43.653447       -79.362017
# ...

# %%
toronto_venues.groupby('Neighborhood').count()
# Out:
#               Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# M4E                               4                       4      4
# M4K                              42                      42     42
# M4L                              20                      20     20
# M4M                              40                      40     40
# M4N                               3                       3      3
# M4P                               7                       7      7
# M4R                              20                      20     20
# M4S                              35                      35     35
# M4T                               2                       2      2
# M4V                              16                      16     16
# M4W                               4                       4      4
# M4X                              45                      45     45
# M4Y                              73                      73     73
# ...

# %%
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 
toronto_grouped=toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped
# Out:
#    Neighborhood  Afghan Restaurant   Airport  Airport Food Court  \
# 0           M4E           0.000000  0.000000            0.000000
# 1           M4K           0.000000  0.000000            0.000000
# 2           M4L           0.000000  0.000000            0.000000
# 3           M4M           0.000000  0.000000            0.000000
# 4           M4N           0.000000  0.000000            0.000000
# 5           M4P           0.000000  0.000000            0.000000
# 6           M4R           0.000000  0.000000            0.000000
# 7           M4S           0.000000  0.000000            0.000000
# 8           M4T           0.000000  0.000000            0.000000
# 9           M4V           0.000000  0.000000            0.000000
# 10          M4W           0.000000  0.000000            0.000000
# 11          M4X           0.000000  0.000000            0.000000
# 12          M4Y           0.013699  0.000000            0.000000
# ...

# %% [markdown]
# #### K means cluster based on the cuisine

# %%
k=5

geocluster=toronto_grouped.drop('Neighborhood', 1)
kmeans = KMeans(n_clusters=k, random_state=0).fit(geocluster)
kmeans.labels_
# Out:
# array([0, 4, 4, 4, 2, 0, 4, 4, 1, 4, 0, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4,
#        3, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4], dtype=int32)

# %%
toronto_grouped.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
toronto_cluster=toronto_grouped[['Cluster Labels','Neighborhood']]
toronto_cluster.columns=['Cluster Labels','Postal Code']
toronto_cluster=pd.merge(toronto_cluster,toronto,on='Postal Code')
toronto_cluster
# Out:
#     Cluster Labels Postal Code           Borough  \
# 0                0         M4E      East Toronto
# 1                4         M4K      East Toronto
# 2                4         M4L      East Toronto
# 3                4         M4M      East Toronto
# 4                2         M4N   Central Toronto
# 5                0         M4P   Central Toronto
# 6                4         M4R   Central Toronto
# 7                4         M4S   Central Toronto
# 8                1         M4T   Central Toronto
# 9                4         M4V   Central Toronto
# 10               0         M4W  Downtown Toronto
# 11               4         M4X  Downtown Toronto
# 12               4         M4Y  Downtown Toronto
# 13               4         M5A  Downtown Toronto
# 14               4         M5B  Downtown Toronto
# 15               4         M5C  Downtown Toronto
# 16               4         M5E  Downtown Toronto
# 17               4         M5G  Downtown Toronto
# ...

# %% [markdown]
# #### K means cluster visualization based on the cuisine

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(k)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_cluster['Latitude'], toronto_cluster['Longitude'], toronto_cluster['Neighborhood'], toronto_cluster['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### K means cluster based on the geolocation coordinates

# %%
tc=toronto[['Postal Code','Latitude','Longitude']]
tc.set_index('Postal Code',inplace=True)
kmeans1 = KMeans(n_clusters=k, random_state=0).fit(tc)
kmeans1.labels_
# Out:
# array([0, 0, 0, 0, 4, 0, 0, 3, 0, 1, 0, 3, 4, 0, 3, 4, 0, 4, 2, 2, 2, 2,
#        1, 2, 3, 1, 2, 3, 1, 2, 3, 2, 0, 0, 0, 0, 0, 0, 4], dtype=int32)

# %%
tc.insert(0, 'Cluster Labels', kmeans1.labels_)

# %%
tc=tc.reset_index()

# %%
to_cl=pd.merge(tc[['Postal Code','Cluster Labels']],toronto,on='Postal Code')
to_cl.head()
# Out:
#   Postal Code  Cluster Labels           Borough  \
# 0         M5A               0  Downtown Toronto
# 1         M7A               0  Downtown Toronto
# 2         M5B               0  Downtown Toronto
# 3         M5C               0  Downtown Toronto
# 4         M4E               4      East Toronto
#
#                                   Neighborhood   Latitude  Longitude
# 0                    Regent Park, Harbourfront  43.654260 -79.360636
# 1  Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# 2                     Garden District, Ryerson  43.657162 -79.378937
# 3                               St. James Town  43.651494 -79.375418
# 4                                  The Beaches  43.676357 -79.293031

# %% [markdown]
# #### K means visualization based on the geolocation

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(k)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(to_cl['Latitude'], to_cl['Longitude'], to_cl['Neighborhood'], to_cl['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
